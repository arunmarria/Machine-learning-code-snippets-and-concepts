# %%
#importing libraries

import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import pandas as pd

# classifiers / models
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder

# data
from sklearn import datasets

# other
from sklearn.metrics import make_scorer, precision_score, f1_score, accuracy_score, roc_curve, roc_auc_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# Import any other modules you use here. 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer

# %% [raw]
# # train test split
#
# X_train, X_test, y_train, y_test = train_test_split(cancer.data,
#                                                     cancer.target,
#                                                     test_size=0.20,
#                                                     random_state=100)
#
#
# # cross_val_score
#
# svm_default = SVC()
# score_default_svm = cross_val_score(svm_default, X_train, y_train, cv=10).mean()
#
#
#
# #Grid SearchCV
# svm_non_default = SVC()
# parameters = {'gamma' : [10**-6,10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1 ]}
# svm_gamma = GridSearchCV(svm_non_default,
#                          param_grid= parameters,
#                         cv =10)
# svm_gamma.fit(X_train, y_train)
# print("The best parameter is ", svm_gamma.best_params_)
# print("And the score is ", svm_gamma.best_score_)
#
#
#
# # setting up preprocessor
# preprocessor = ColumnTransformer( transformers= [
#     ("stand_scaler", StandardScaler(), numerical_features),
#     ("ohe", OneHotEncoder(drop="first"), categorical_features)
# ])
#
#
#
# ## Applying transformations to training data set
# X_train = pd.DataFrame(preprocessor.fit_transform(X_train),
#     index = X_train.index,
#              columns = numerical_features +list(
#              preprocessor.named_transformers_['ohe'].get_feature_names(categorical_features)))
#
# ## applying same preprocessing to test dataset
#
# X_test = X_test.drop(['phone number', 'state'],axis = 1)
# X_test = pd.DataFrame(preprocessor.transform(X_test),
#                      index = X_test.index,
#                      columns= X_train.columns)
#
#
# ## confusion matrix
# confusion_matrix(y_train, logistic_model.predict(X_train))
# tn, fp, fn, tp = confusion_matrix()
#
#             ACtual
#             -    +
# Predicted -
#           +
#
#
#
# # ROC curver
# fpr, tpr, thresholds = roc_curve(y_test, logistic_model.predict(X_test))
#
# plt.plot(fpr, tpr);
# plt.plot((0,1),(0,1),'--k');
# plt.xlabel('false positive rate');
# plt.ylabel('true positive rate');
#
#
# ##plotting hyperparameter against error
#
#
# poly_model = PolynomialFeatures()
# results = {'Degree':[], 'CV score':[] }
# for degree in range(41):
#
#     poly_model = PolynomialFeatures(degree=degree)
#     Xpoly = poly_model.fit_transform(X)
#     results['Degree'].append(degree)
#     results['CV score'].append(cross_val_score(lm,Xpoly,y, cv=10).mean())
# ​
# ​
# results_df = pd.DataFrame(results)
# results_df
#
#
# ## creating pipeline
# poly_model2 = PolynomialFeatures()
#
#
# preprocessor = ColumnTransformer(transformers=[
#     ('poly' ,poly_model2, feature )])
#
# lin_model_pipeline = Pipeline(steps = [
#     ('preprocessor', preprocessor),
#     ('regressor', LinearRegression())
# ])
#
# lm_hypParam_opt = GridSearchCV(lin_model_pipeline,
#                                param_grid={'preprocessor__poly__degree': list(range(41))},
#                                cv=10)
# lm_hypParam_opt.fit(X2,y)
# # poly_model2.get_parms()
